# %%
from astroquery.lamda import Lamda, parse_lamda_datafile, write_lamda_datafile

def cut_lamda_file(oldfile: str, newfile: str, maxlevel: int) -> None:
	if oldfile == newfile:
		raise ValueError("oldfile and newfile must be different") 
	collis, trans, enlev = parse_lamda_datafile(oldfile)
	allowedcollis = dict()
	for species, data in collis.items():
		allowedcollis[species] = data[data['Upper'] <= maxlevel]
		ncollisions = len(allowedcollis[species])
		allowedcollis[species].meta["ntrans"] = ncollisions

	allowedtrans = trans[trans['Upper'] <= maxlevel]
	ntrans = len(allowedtrans)
	print(allowedtrans.meta)
	allowedtrans.meta["radtrans"] = ntrans
	allowedenlev = enlev[enlev['Level'] <= maxlevel]
	nlev = len(allowedenlev)
	print(allowedenlev.meta)
	allowedenlev.meta["nenergylevels"] = nlev
	write_lamda_datafile(newfile, (allowedcollis, allowedtrans, allowedenlev))

maxlev = 12
cut_lamda_file("co.txt", f"co_cut_{maxlev}.txt", maxlev)
print(parse_lamda_datafile(f"co_cut_{maxlev}.txt"))
newcollis, newtrans, newenlev = parse_lamda_datafile(f"co_cut_{maxlev}.txt")
# Out:
# {'radtrans': 40}
# {'molecule': 'CO', 'molwt': 28.0, 'nenergylevels': 41}
# ({'PH2': <Table length=66>
# Transition Upper Lower C_ij(T=2) ... C_ij(T=1000) C_ij(T=2000) C_ij(T=3000)
#   int64    int64 int64  float64  ...   float64      float64      float64
# ---------- ----- ----- --------- ... ------------ ------------ ------------
#          1     2     1 2.954e-11 ...    3.409e-11    3.598e-11    3.818e-11
#          2     3     1  2.87e-11 ...    4.885e-11     5.61e-11    6.083e-11
#          3     3     2  8.89e-11 ...      7.2e-11    7.596e-11    7.983e-11
#          4     4     1  4.65e-12 ...    1.748e-11    1.837e-11    1.904e-11
#          5     4     2 4.734e-11 ...    8.204e-11     9.63e-11    1.049e-10
#          6     4     3 1.108e-10 ...    9.062e-11     9.73e-11    1.022e-10
#          7     5     1 2.819e-12 ...     1.06e-11    1.271e-11    1.309e-11
#          8     5     2 6.145e-12 ...    3.989e-11    3.822e-11    3.439e-11
#          9     5     3 6.058e-11 ...    8.953e-11    9.551e-11    9.291e-11
#         10     5     4 8.243e-11 ...    9.479e-11    8.774e-11    7.702e-11
#        ...   ...   ...       ... ...          ...          ...          ...
#         57    12     2 4.342e-14 ...    3.308e-12    4.337e-12    4.825e-12
#         58    12     3 1.801e-13 ...    7.703e-12    1.107e-11    1.248e-11
#         59    12     4 4.859e-13 ...     7.81e-12     1.07e-11    1.207e-11
#         60    12     5 1.748e-12 ...      1.8e-11    2.392e-11    2.601e-11
#         61    12     6 3.194e-12 ...     1.48e-11    2.076e-11    2.334e-11
#         62    12     7 1.088e-11 ...    3.641e-11    4.364e-11    4.547e-11
#         63    12     8 1.478e-11 ...    3.523e-11    4.535e-11      4.9e-11
#         64    12     9 4.193e-11 ...    6.421e-11     7.08e-11    7.112e-11
#         65    12    10 6.441e-11 ...    1.101e-10    1.275e-10    1.311e-10
#         66    12    11 7.354e-11 ...    1.012e-10    1.068e-10    1.042e-10, 'OH2': <Table length=66>
# Transition Upper Lower C_ij(T=2) ... C_ij(T=1000) C_ij(T=2000) C_ij(T=3000)
#   int64    int64 int64  float64  ...   float64      float64      float64
# ---------- ----- ----- --------- ... ------------ ------------ ------------
#          1     2     1 4.231e-11 ...    3.756e-11    3.946e-11     4.17e-11
#          2     3     1 6.132e-11 ...     5.78e-11     6.51e-11    6.963e-11
#          3     3     2 8.368e-11 ...    7.756e-11    8.249e-11    8.638e-11
#          4     4     1 6.017e-12 ...    1.813e-11    1.949e-11    2.027e-11
#          5     4     2 7.455e-11 ...    9.423e-11    1.091e-10    1.178e-10
#          6     4     3 9.578e-11 ...    9.602e-11    1.043e-10    1.095e-10
#          7     5     1 5.777e-12 ...    1.143e-11    1.409e-11    1.513e-11
#          8     5     2 8.554e-12 ...     4.39e-11    4.475e-11    4.364e-11
#          9     5     3 7.852e-11 ...    1.008e-10    1.117e-10    1.149e-10
#         10     5     4 8.495e-11 ...    1.064e-10     1.07e-10    1.031e-10
#        ...   ...   ...       ... ...          ...          ...          ...
#         57    12     2 7.633e-14 ...    3.469e-12    4.827e-12    5.541e-12
#         58    12     3 2.877e-13 ...    8.056e-12    1.258e-11    1.489e-11
#         59    12     4 7.422e-13 ...     8.44e-12      1.2e-11    1.386e-11
#         60    12     5 2.252e-12 ...    1.931e-11    2.697e-11    3.028e-11
#         61    12     6 4.006e-12 ...    1.614e-11    2.308e-11    2.645e-11
#         62    12     7 1.157e-11 ...    3.917e-11    4.784e-11    5.055e-11
#         63    12     8  1.57e-11 ...    3.658e-11    4.847e-11    5.352e-11
#         64    12     9 4.129e-11 ...     6.86e-11    7.473e-11    7.462e-11
#         65    12    10 6.658e-11 ...    1.173e-10    1.315e-10    1.338e-10
#         66    12    11 7.785e-11 ...    1.072e-10    1.079e-10    1.021e-10}, <Table length=11>
# Transition Upper Lower EinsteinA  Frequency   E_u(K)
#   int64    int64 int64  float64    float64   float64
# ---------- ----- ----- --------- ----------- -------
#          1     2     1 7.203e-08 115.2712018    5.53
#          2     3     2  6.91e-07     230.538    16.6
#          3     4     3 2.497e-06 345.7959899   33.19
#          4     5     4 6.126e-06 461.0407682   55.32
#          5     6     5 1.221e-05 576.2679305   82.97
#          6     7     6 2.137e-05 691.4730763  116.16
#          7     8     7 3.422e-05  806.651806  154.87
#          8     9     8 5.134e-05    921.7997  199.11
#          9    10     9  7.33e-05 1036.912393  248.88
#         10    11    10 0.0001006 1151.985452  304.16
#         11    12    11 0.0001339 1267.014486  364.97, <Table length=12>
# Level     Energy    Weight  J
# int64    float64    int64  str2
# ----- ------------- ------ ----
#     1           0.0      1    0
#     2   3.845033413      3    1
#     3  11.534919938      5    2
#     4  23.069512649      7    3
#     5  38.448164669      9    4
#     6  57.670329083     11    5
#     7  80.735459105     13    6
#     8 107.642407981     15    7
#     9 138.390328288     17    8
#    10 172.978074417     19    9
#    11 211.404098498     21   10
#    12 253.667154063     23   11)
